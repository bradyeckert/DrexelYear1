# %%
import pandas as pd
import numpy as np

data = pd.read_csv('exoplanets.csv', skiprows=78)

# %%
data
# Out:
#     pl_hostname pl_letter        pl_name              pl_discmethod  \
# 0        AU Mic         b       AU Mic b                    Transit
# 1      DS Tuc A         b     DS Tuc A b                    Transit
# 2       GJ 1252         b      GJ 1252 b                    Transit
# 3        GJ 143         b       GJ 143 b                    Transit
# 4       GJ 3473         b      GJ 3473 b                    Transit
# ..          ...       ...            ...                        ...
# 77      TOI-954         b      TOI-954 b                    Transit
# 78     WASP-126         c     WASP-126 c  Transit Timing Variations
# 79      WASP-18         c      WASP-18 c  Transit Timing Variations
# 80  WD 1856+534         b  WD 1856+534 b                    Transit
# 81     HD 39091         c       pi Men c                    Transit
#
#     pl_controvflag  pl_pnum  pl_orbper  pl_orbpererr1  pl_orbpererr2  \
# 0                0        1   8.463210       0.000040      -0.000040
# ...

# %%
hist = data.hist(column='st_mass',bins='scott')

# %%
data.describe(include=np.number)
# Out:
#        pl_controvflag    pl_pnum  pl_orbper  pl_orbpererr1  pl_orbpererr2  \
# count            82.0  82.000000  82.000000      82.000000      82.000000
# mean              0.0   1.804878  11.529105       0.012157      -0.009447
# std               0.0   0.792543  15.658436       0.051894       0.037594
# min               0.0   1.000000   0.462929       0.000001      -0.230000
# 25%               0.0   1.000000   3.456424       0.000033      -0.000768
# 50%               0.0   2.000000   6.151985       0.000180      -0.000180
# 75%               0.0   2.000000  12.268250       0.000692      -0.000034
# max               0.0   3.000000  95.174000       0.360000      -0.000001
#
#        pl_orbperlim  pl_orbsmax  pl_orbsmaxerr1  pl_orbsmaxerr2  \
# count          82.0   78.000000       77.000000       77.000000
# mean            0.0    0.082419        0.002589       -0.002762
# std             0.0    0.078448        0.004172        0.004748
# ...

# %%
removing_columns=['pl_hostname','pl_letter','pl_name','pl_discmethod','pl_controvflag','pl_orbperlim','pl_orbsmaxlim','st_tefflim','st_masslim','st_radlim','pl_radjlim','pl_kepflag','pl_k2flag','st_distlim','gaia_distlim','st_optmaglim','gaia_gmagerr','gaia_gmaglim','rowupdate','pl_facility','pl_bmassprov','ra_str','dec_str','st_optband','rowupdate','pl_facility']
# list contains non-numerical and 0 stdev columns
print(len(removing_columns))
# Out:
# 26

# %%
reduced_data = data.drop(removing_columns, axis=1)

# %%
reduced_data.describe()
# Out:
#          pl_pnum  pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbsmax  \
# count  82.000000  82.000000      82.000000      82.000000   78.000000
# mean    1.804878  11.529105       0.012157      -0.009447    0.082419
# std     0.792543  15.658436       0.051894       0.037594    0.078448
# min     1.000000   0.462929       0.000001      -0.230000    0.006220
# 25%     1.000000   3.456424       0.000033      -0.000768    0.035000
# 50%     2.000000   6.151985       0.000180      -0.000180    0.061780
# 75%     2.000000  12.268250       0.000692      -0.000034    0.105300
# max     3.000000  95.174000       0.360000      -0.000001    0.460700
#
#        pl_orbsmaxerr1  pl_orbsmaxerr2  pl_orbeccen  pl_orbeccenerr1  \
# count       77.000000       77.000000    75.000000        39.000000
# mean         0.002589       -0.002762     0.081795         0.073528
# std          0.004172        0.004748     0.096242         0.065153
# ...

# %%
# Im gonna remove error columns to idealize the dataset
errors = ['pl_orbpererr1','pl_orbpererr2','pl_orbsmaxerr1','pl_orbsmaxerr2','pl_orbeccenerr1','pl_orbeccenerr2','pl_orbinclerr1','pl_orbinclerr2','pl_bmassjerr1','pl_bmassjerr2','pl_radjerr1','pl_radjerr2','pl_denserr1','pl_denserr2','st_disterr1','st_disterr2','gaia_disterr1','gaia_disterr2','st_optmagerr','st_tefferr1','st_tefferr2','st_masserr1','st_masserr2','st_raderr1','st_raderr2']
gooddata = reduced_data.drop(errors, axis=1)

# %%
gooddata.describe()
# Out:
#          pl_pnum  pl_orbper  pl_orbsmax  pl_orbeccen  pl_orbeccenlim  \
# count  82.000000  82.000000   78.000000    75.000000       79.000000
# mean    1.804878  11.529105    0.082419     0.081795        0.126582
# std     0.792543  15.658436    0.078448     0.096242        0.334629
# min     1.000000   0.462929    0.006220     0.000000        0.000000
# 25%     1.000000   3.456424    0.035000     0.000000        0.000000
# 50%     2.000000   6.151985    0.061780     0.057000        0.000000
# 75%     2.000000  12.268250    0.105300     0.125000        0.000000
# max     3.000000  95.174000    0.460700     0.435000        1.000000
#
#        pl_orbincl  pl_orbincllim  pl_bmassj  pl_bmassjlim    pl_radj  ...  \
# count   72.000000      78.000000  60.000000     70.000000  80.000000  ...
# mean    87.440861       0.012821   0.639154      0.085714   0.462388  ...
# std      2.758146       0.113228   1.944982      0.281963   0.450150  ...
# ...

# %%
gooddata.iloc[0]
# Out:
# pl_pnum              1.000000
# pl_orbper            8.463210
# pl_orbsmax           0.066000
# pl_orbeccen          0.100000
# pl_orbeccenlim       0.000000
# pl_orbincl                NaN
# pl_orbincllim        0.000000
# pl_bmassj            0.180000
# pl_bmassjlim         1.000000
# pl_radj              0.375000
# pl_dens              4.400000
# pl_denslim           1.000000
# pl_ttvflag           0.000000
# pl_nnotes            0.000000
# ra                 311.289703
# dec                -31.340899
# st_dist              9.790000
# gaia_dist            9.720000
# st_optmag            8.810000
# gaia_gmag            7.840000
# st_teff           3700.000000
# st_mass              0.500000
# st_rad               0.750000
# Name: 0, dtype: float64

# %%
afewmore = ['pl_orbeccenlim','pl_orbincllim','pl_bmassjlim','pl_denslim','pl_ttvflag','pl_nnotes','gaia_dist','gaia_gmag','st_teff','ra','dec','st_dist']
thedata = gooddata.drop(afewmore, axis=1)

# %%
thedata.iloc[0]
# so number of planets in system, Orbital Period, Orbit Semi-Major Axis, Orbital Eccentricity, Orbital Inclination, Planet Mass, Planet Radius, Planet Density, Right Ascension, Declination, Distance to Star, Stellar Magnitude, Stellar Mass, Stellar Radius
# Out:
# pl_pnum        1.00000
# pl_orbper      8.46321
# pl_orbsmax     0.06600
# pl_orbeccen    0.10000
# pl_orbincl         NaN
# pl_bmassj      0.18000
# pl_radj        0.37500
# pl_dens        4.40000
# st_optmag      8.81000
# st_mass        0.50000
# st_rad         0.75000
# Name: 0, dtype: float64

# %%
thedata
# Out:
#     pl_pnum  pl_orbper  pl_orbsmax  pl_orbeccen  pl_orbincl  pl_bmassj  \
# 0         1   8.463210     0.06600        0.100         NaN    0.18000
# 1         1   8.138268         NaN        0.000      89.500        NaN
# 2         1   0.518235     0.00916        0.000      85.000    0.00658
# 3         2  35.612530     0.19150        0.188      89.330    0.07142
# 4         2   1.198003     0.01589        0.000      87.950    0.00585
# ..      ...        ...         ...          ...         ...        ...
# 77        1   3.684973     0.04963        0.140      84.400    0.17400
# 78        2   7.630000         NaN        0.050      85.500    0.20199
# 79        2   2.155800     0.03500        0.015         NaN    0.17368
# 80        1   1.407941     0.02040        0.000      88.778   13.80000
# 81        2   6.267900     0.06839        0.000      87.456    0.01517
#
#     pl_radj  pl_dens  st_optmag  st_mass  st_rad
# 0     0.375     4.40      8.810     0.50    0.75
# ...

# %%
import seaborn as sns
sns.pairplot(thedata, diag_kind='hist', hue='pl_pnum')

# %%
thedata.mean()
# Out:
# pl_pnum         1.804878
# pl_orbper      11.529105
# pl_orbsmax      0.082419
# pl_orbeccen     0.081795
# pl_orbincl     87.440861
# pl_bmassj       0.639154
# pl_radj         0.462388
# pl_dens         3.862750
# st_optmag      10.719657
# st_mass         0.801098
# st_rad          0.886829
# dtype: float64

# %%
meanie=thedata-thedata.mean()
meanie
# Out:
#      pl_pnum  pl_orbper  pl_orbsmax  pl_orbeccen  pl_orbincl  pl_bmassj  \
# 0  -0.804878  -3.065895   -0.016419     0.018205         NaN  -0.459154
# 1  -0.804878  -3.390837         NaN    -0.081795    2.059139        NaN
# 2  -0.804878 -11.010870   -0.073259    -0.081795   -2.440861  -0.632574
# 3   0.195122  24.083425    0.109081     0.106205    1.889139  -0.567734
# 4   0.195122 -10.331102   -0.066529    -0.081795    0.509139  -0.633304
# ..       ...        ...         ...          ...         ...        ...
# 77 -0.804878  -7.844132   -0.032789     0.058205   -3.040861  -0.465154
# 78  0.195122  -3.899105         NaN    -0.031795   -1.940861  -0.437164
# 79  0.195122  -9.373305   -0.047419    -0.066795         NaN  -0.465474
# 80 -0.804878 -10.121165   -0.062019    -0.081795    1.337139  13.160846
# 81  0.195122  -5.261205   -0.014029    -0.081795    0.015139  -0.623984
#
#      pl_radj  pl_dens  st_optmag   st_mass    st_rad
# ...

# %%
sns.pairplot(meanie, diag_kind='hist', hue='pl_pnum')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Scale the data
#scaler = StandardScaler()
#scaleddata = scaler.fit_transform(thedata)

# Apply PCA
pca = PCA(n_components=5)
pca.fit(thedata)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-263d018665dc> in <module>
#       8 # Apply PCA
#       9 pca = PCA(n_components=5)
# ---> 10 pca.fit(thedata)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py in fit(self, X, y)
#     349             Returns the instance itself.
#     350         """
# --> 351         self._fit(X)
#     352         return self
#     353
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     395                             'TruncatedSVD for a possible alternative.')
#     396
# --> 397         X = self._validate_data(X, dtype=[np.float64, np.float32],
#     398                                 ensure_2d=True, copy=self.copy)
#     399
#
# ...
